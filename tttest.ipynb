# %% [markdown]
# <a href="https://colab.research.google.com/github/atamaoka/github-slideshow/blob/master/tttest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread("/content/drive/MyDrive/flowey.jpg")

plt.imshow(img)

# %%
import csv
